# %% [markdown]
# <a href="https://colab.research.google.com/github/JyotiKuber/CodeDivisionProject/blob/main/Bus_Data_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bus Journey to find how may hours each bus is on route V1 - Calculating 5 minutes data in one hour**

# %% [markdown]
# In terms of the bus data, a question that I would like answer is how many hours are buses which have Euro III engines (over 15 years old) on the road each day when data has been collected. The data is collected every Wednesday and has a record for every 5 minute interval from 6am to 11.55pm. In each 5 minute interval there is data on every bus out on a route.
#
# First version here is to calculate how many hours each bus is on route (assuming that if it is recorded in one 5 minute interval then
# we can assume that it was on the route for the whole of that 5 minutes) for 1 hour in given day 04-Jan-2023 at 11:05 pm.
#
# Then, using a list of all the buses in the dataset, which has then been updated with the engine type, and then to filter for just the Euro III buses and
# calculate the total number of hours.

# %% [markdown]
# ## **Dataset Description **

# %% [markdown]
# The data for bus journeys is in this folder on Github:
#
# python-programming-for-data/Datasets at main · futureCodersSE/python-programming-for-data
#
# The folder to get the individual links for each file.
#
# https://raw.githubusercontent.com/futureCodersSE/python-programming-for-data/main/Datasets/bus-journey-data-23-01-04/busdata_23-01-04_23-05.json
#
#
# and used python to generate links to the files as the link will be the same right up to the filename at the end (ie the file for 23-05)

# %%
import requests
import json
import pandas as pd

url= "https://raw.githubusercontent.com/futureCodersSE/python-programming-for-data/main/Datasets/bus-journey-data-23-01-04/busdata_23-01-04_23-05.json"
bus_data = requests.get(url).json()
file_name = url.split('/')[-1]
file_name = file_name.split('.')[0]
recording_date = file_name.split('_')[1]
recording_time = file_name.split('_')[2]
display(recording_date)
display(recording_time)
# Out:
# '23-01-04'
# '23-05'

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# RecordedAtTime 2023-01-04T16:31:47+00:00
#
# ItemIdentifier e9de3429-97b4-40c2-9562-a078fe02c673
#
# ValidUntilTime 2023-01-04T23:10:25.372229
#
# MonitoredVehicleJourney {'LineRef': '82', 'DirectionRef': 'inbound', 'FramedVehicleJourneyRef': {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1103'}, 'PublishedLineName': '82', 'OperatorRef': 'AKSS', 'OriginRef': '2400A001090A', 'OriginName': 'Parade', 'DestinationRef': '2400A000640A', 'DestinationName': 'Royal_Star_Arcade', 'OriginAimedDepartureTime': '2023-01-04T16:05:00+00:00', 'DestinationAimedArrivalTime': '2023-01-04T16:37:00+00:00', 'VehicleLocation': {'Longitude': '0.520889', 'Latitude': '51.272936'}, 'BlockRef': '0311', 'VehicleRef': '4295'}
#
# Extensions {'VehicleJourney': {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '82', 'JourneyCode': '1605'}}, 'VehicleUniqueId': '4295'}}

# %% [markdown]
# I installed JSON Formatter in Google chrome browser(from chrome webstore). Now after restarting Chrome, I can see parsed JSON which is more readable to work.

# %%
for item in bus_data:

        print(item['RecordedAtTime'])
        vehicle_journey_data = item['MonitoredVehicleJourney']
        journey_keys_list = list(vehicle_journey_data.keys())

        for key in journey_keys_list:
            print( key, "-",vehicle_journey_data[key])

        extensions_data = item['Extensions']
        extensions_keys_list = list(extensions_data.keys())
        for key1 in extensions_keys_list:
            print( key1, "-",extensions_data[key1])
# Out:
# 2023-01-04T16:31:47+00:00
# LineRef - 82
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1103'}
# PublishedLineName - 82
# OperatorRef - AKSS
# OriginRef - 2400A001090A
# OriginName - Parade
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T16:05:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:37:00+00:00
# VehicleLocation - {'Longitude': '0.520889', 'Latitude': '51.272936'}
# BlockRef - 0311
# VehicleRef - 4295
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '82', 'JourneyCode': '1605'}}, 'VehicleUniqueId': '4295'}
# 2023-01-04T16:01:58+00:00
# LineRef - 693
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 693
# OperatorRef - AKSS
# OriginRef - 249000000309
# OriginName - Breton_Road
# DestinationRef - 249000000171
# DestinationName - Linwood_Avenue
# OriginAimedDepartureTime - 2023-01-04T15:28:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:01:00+00:00
# VehicleLocation - {'Longitude': '0.470826', 'Latitude': '51.399213'}
# BlockRef - 0523
# VehicleRef - 4264
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '693', 'JourneyCode': '1528'}}, 'VehicleUniqueId': '4264'}
# 2023-01-04T23:04:59+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1150'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A050680A
# OriginName - Chequers_Bus_Station
# DestinationRef - 249000000638
# DestinationName - Duncan_Road
# OriginAimedDepartureTime - 2023-01-04T23:10:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:48:00+00:00
# VehicleLocation - {'Longitude': '0.526476', 'Latitude': '51.272811'}
# BlockRef - 0589
# VehicleRef - 6412
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '2310'}}, 'VehicleUniqueId': '6412'}
# 2022-12-01T16:19:00+00:00
# LineRef - 5
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-01', 'DatedVehicleJourneyRef': '1037'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A073520A
# OriginName - The_Swan
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2022-12-01T14:47:00+00:00
# DestinationAimedArrivalTime - 2022-12-01T15:59:00+00:00
# VehicleLocation - {'Longitude': '0.52374', 'Latitude': '51.27382'}
# VehicleRef - 6408
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '0300'}}, 'VehicleUniqueId': '6408'}
# 2022-12-15T16:40:09+00:00
# LineRef - 576
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-15', 'DatedVehicleJourneyRef': '1006'}
# PublishedLineName - 576
# OperatorRef - AKSS
# OriginRef - 2400102279
# OriginName - Cornwallis_Academy
# DestinationRef - 240082419
# DestinationName - Asda
# OriginAimedDepartureTime - 2022-12-15T15:10:00+00:00
# DestinationAimedArrivalTime - 2022-12-15T16:39:00+00:00
# VehicleLocation - {'Longitude': '0.526746', 'Latitude': '51.272'}
# BlockRef - 0544
# VehicleRef - 4121
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '576', 'JourneyCode': '1510'}}, 'VehicleUniqueId': '4121'}
# 2023-01-04T14:36:12+00:00
# LineRef - 7
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1038'}
# PublishedLineName - 7
# OperatorRef - AKSS
# OriginRef - 2400A050670A
# OriginName - Chequers_Bus_Station
# DestinationRef - 2400A013900A
# DestinationName - Railway_Station
# OriginAimedDepartureTime - 2023-01-04T14:02:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T15:35:00+00:00
# VehicleLocation - {'Longitude': '0.380305', 'Latitude': '51.258686'}
# Bearing - 310.0
# BlockRef - 0508
# VehicleRef - 6520
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4007', 'JourneyCode': '1402'}}, 'VehicleUniqueId': '6520'}
# 2023-01-04T18:47:58+00:00
# LineRef - 132
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1096'}
# PublishedLineName - 132
# OperatorRef - AKSS
# OriginRef - 249000000823
# OriginName - Hempstead_Valley_Shopping_Centre
# DestinationRef - 2490101071
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:10:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:45:00+00:00
# VehicleLocation - {'Longitude': '0.551128', 'Latitude': '51.382513'}
# BlockRef - 0511
# VehicleRef - 4309
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '132', 'JourneyCode': '1810'}}, 'VehicleUniqueId': '4309'}
# 2023-01-04T20:21:59+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1134'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A050680A
# OriginName - Chequers_Bus_Station
# DestinationRef - 249000000638
# DestinationName - Duncan_Road
# OriginAimedDepartureTime - 2023-01-04T19:40:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:18:00+00:00
# VehicleLocation - {'Longitude': '0.550431', 'Latitude': '51.383981'}
# BlockRef - 0586
# VehicleRef - 6476
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1940'}}, 'VehicleUniqueId': '6476'}
# 2022-12-21T16:41:18+00:00
# LineRef - 190
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-21', 'DatedVehicleJourneyRef': '1062'}
# PublishedLineName - 190
# OperatorRef - AKSS
# OriginRef - 2400109567
# OriginName - Barrack_Row
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2022-12-21T15:48:00+00:00
# DestinationAimedArrivalTime - 2022-12-21T16:45:00+00:00
# VehicleLocation - {'Longitude': '0.524059', 'Latitude': '51.384895'}
# BlockRef - 0501
# VehicleRef - 6411
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '190', 'JourneyCode': '1548'}}, 'VehicleUniqueId': '6411'}
# 2023-01-04T20:03:27+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1132'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A050680A
# OriginName - Chequers_Bus_Station
# DestinationRef - 249000000638
# DestinationName - Duncan_Road
# OriginAimedDepartureTime - 2023-01-04T19:25:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:03:00+00:00
# VehicleLocation - {'Longitude': '0.550435', 'Latitude': '51.382558'}
# BlockRef - 0585
# VehicleRef - 6472
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1925'}}, 'VehicleUniqueId': '6472'}
# 2022-12-05T09:35:18+00:00
# LineRef - 85
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-05', 'DatedVehicleJourneyRef': '1027'}
# PublishedLineName - 85
# OperatorRef - AKSS
# OriginRef - 2400A001290A
# OriginName - Freeman_Way
# DestinationRef - 2400A050610A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2022-12-05T09:17:00+00:00
# DestinationAimedArrivalTime - 2022-12-05T09:34:00+00:00
# VehicleLocation - {'Longitude': '0.526576', 'Latitude': '51.273183'}
# BlockRef - 0354
# VehicleRef - 6406
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '85', 'JourneyCode': '0917'}}, 'VehicleUniqueId': '6406'}
# 2022-12-23T13:03:09+00:00
# LineRef - 190
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-23', 'DatedVehicleJourneyRef': '1038'}
# PublishedLineName - 190
# OperatorRef - AKSS
# OriginRef - 2400109567
# OriginName - Barrack_Row
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2022-12-23T12:20:00+00:00
# DestinationAimedArrivalTime - 2022-12-23T13:04:00+00:00
# VehicleLocation - {'Longitude': '0.55069', 'Latitude': '51.383556'}
# BlockRef - 0392
# VehicleRef - SP_GM
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '190', 'JourneyCode': '1220'}}, 'VehicleUniqueId': 'SPARE GM'}
# 2023-01-04T19:31:08+00:00
# LineRef - 140
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1087'}
# PublishedLineName - 140
# OperatorRef - AKSS
# OriginRef - 2490101072
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000040
# DestinationName - Bligh_Way_Shops
# OriginAimedDepartureTime - 2023-01-04T19:07:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:27:00+00:00
# VehicleLocation - {'Longitude': '0.460474', 'Latitude': '51.394723'}
# BlockRef - 0508
# VehicleRef - 4269
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '140', 'JourneyCode': '1907'}}, 'VehicleUniqueId': '4269'}
# 2023-01-04T20:13:05+00:00
# LineRef - 191
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4003'}
# PublishedLineName - 191
# OperatorRef - AKSS
# OriginRef - 249000000083
# OriginName - Wylie_Road
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T19:50:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:16:00+00:00
# VehicleLocation - {'Longitude': '0.522785', 'Latitude': '51.38309'}
# BlockRef - 0503
# VehicleRef - 4061
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '191', 'JourneyCode': '1950'}}, 'VehicleUniqueId': '4061'}
# 2023-01-03T10:30:01+00:00
# LineRef - 140
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-03', 'DatedVehicleJourneyRef': '1032'}
# PublishedLineName - 140
# OperatorRef - AKSS
# OriginRef - 249000000040
# OriginName - Bligh_Way_Shops
# DestinationRef - 2490101072
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-03T10:07:00+00:00
# DestinationAimedArrivalTime - 2023-01-03T10:31:00+00:00
# VehicleLocation - {'Longitude': '0.524193', 'Latitude': '51.385005'}
# BlockRef - 0381
# VehicleRef - 4265
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '140', 'JourneyCode': '1007'}}, 'VehicleUniqueId': '4265'}
# 2023-01-04T22:57:56+00:00
# LineRef - 177
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4006'}
# PublishedLineName - 177
# OperatorRef - AKSS
# OriginRef - 249000000614
# OriginName - Plantation_Road
# DestinationRef - 2400A034340A
# DestinationName - Alexandra_Hospital
# OriginAimedDepartureTime - 2023-01-04T22:10:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:07:00+00:00
# VehicleLocation - {'Longitude': '0.525173', 'Latitude': '51.34073'}
# BlockRef - 0173
# VehicleRef - 1637
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '177', 'JourneyCode': '2210'}}, 'VehicleUniqueId': '1637'}
# 2022-12-17T14:30:05+00:00
# LineRef - 72
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-17', 'DatedVehicleJourneyRef': '6013'}
# PublishedLineName - 72
# OperatorRef - AKSS
# OriginRef - 2400A071670A
# OriginName - Asda
# DestinationRef - 2400A050690A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2022-12-17T13:30:00+00:00
# DestinationAimedArrivalTime - 2022-12-17T14:20:00+00:00
# VehicleLocation - {'Longitude': '0.52662', 'Latitude': '51.272318'}
# BlockRef - 0508
# VehicleRef - 4464
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '72', 'JourneyCode': '1330'}}, 'VehicleUniqueId': '4464'}
# 2023-01-04T18:55:39+00:00
# LineRef - 82
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1126'}
# PublishedLineName - 82
# OperatorRef - AKSS
# OriginRef - 2400A000640A
# OriginName - Royal_Star_Arcade
# DestinationRef - 2400A001090A
# DestinationName - Parade
# OriginAimedDepartureTime - 2023-01-04T18:34:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:58:00+00:00
# VehicleLocation - {'Longitude': '0.556245', 'Latitude': '51.240545'}
# BlockRef - 0314
# VehicleRef - 6139
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '82', 'JourneyCode': '1834'}}, 'VehicleUniqueId': '6139'}
# 2023-01-03T08:01:25+00:00
# LineRef - 694
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-03', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 694
# OperatorRef - AKSS
# OriginRef - 2400A017470A
# OriginName - Forge_Lane
# DestinationRef - 249000000311
# DestinationName - Grammar_Schools
# OriginAimedDepartureTime - 2023-01-03T07:20:00+00:00
# DestinationAimedArrivalTime - 2023-01-03T08:08:00+00:00
# VehicleLocation - {'Longitude': '0.499365', 'Latitude': '51.371285'}
# BlockRef - 0519
# VehicleRef - 4267
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '694', 'JourneyCode': '0720'}}, 'VehicleUniqueId': '4267'}
# 2023-01-04T09:17:24+00:00
# LineRef - 100
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1004'}
# PublishedLineName - 100
# OperatorRef - AKSS
# OriginRef - 249000000700
# OriginName - Chatham_Railway_Station
# DestinationRef - 249000000125
# DestinationName - Goldcrest_Drive
# OriginAimedDepartureTime - 2023-01-04T08:37:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T08:49:00+00:00
# VehicleLocation - {'Longitude': '0.53765', 'Latitude': '51.402308'}
# BlockRef - 0511
# VehicleRef - 6440
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '100', 'JourneyCode': '0837'}}, 'VehicleUniqueId': '6440'}
# 2023-01-04T13:57:31+00:00
# LineRef - 570
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 570
# OperatorRef - AKSS
# OriginRef - 2400A073550A
# OriginName - The_Bull
# DestinationRef - 2400A050690A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T07:07:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T08:21:00+00:00
# VehicleLocation - {'Longitude': '0.523953', 'Latitude': '51.261371'}
# BlockRef - 0543
# VehicleRef - SP_MD
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '570', 'JourneyCode': '0707'}}, 'VehicleUniqueId': 'SPARE MD'}
# 2022-11-22T15:55:03+00:00
# LineRef - 658
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-11-22', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 658
# OperatorRef - AKSS
# OriginRef - 249000000311
# OriginName - Grammar_Schools
# DestinationRef - 2400A074460A
# DestinationName - Boxley_Road
# OriginAimedDepartureTime - 2022-11-22T15:30:00+00:00
# DestinationAimedArrivalTime - 2022-11-22T16:09:00+00:00
# VehicleLocation - {'Longitude': '0.522259', 'Latitude': '51.353835'}
# BlockRef - 0513
# VehicleRef - 6437
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '658', 'JourneyCode': '1530'}}, 'VehicleUniqueId': '6437'}
# 2023-01-04T18:52:30+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1116'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A000780A
# OriginName - Pudding_Lane
# DestinationRef - 249000000408
# DestinationName - Beechings_Green
# OriginAimedDepartureTime - 2023-01-04T17:44:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:48:00+00:00
# VehicleLocation - {'Longitude': '0.550845', 'Latitude': '51.382635'}
# BlockRef - 0587
# VehicleRef - 6481
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1744'}}, 'VehicleUniqueId': '6481'}
# 2023-01-04T21:07:46+00:00
# LineRef - 700
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1066'}
# PublishedLineName - 700
# OperatorRef - AKSS
# OriginRef - 2400A070100A
# OriginName - Bus_Station
# DestinationRef - 2490101072
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T20:30:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T21:07:00+00:00
# VehicleLocation - {'Longitude': '0.523908', 'Latitude': '51.38472'}
# BlockRef - 0354
# VehicleRef - 6441
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '700', 'JourneyCode': '2030'}}, 'VehicleUniqueId': '6441'}
# 2023-01-04T18:35:29+00:00
# LineRef - 5
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1045'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A073520A
# OriginName - The_Swan
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2023-01-04T17:36:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:44:00+00:00
# VehicleLocation - {'Longitude': '0.530408', 'Latitude': '51.259723'}
# BlockRef - 0527
# VehicleRef - 6438
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '1736'}}, 'VehicleUniqueId': '6438'}
# 2023-01-04T15:46:26+00:00
# LineRef - 101
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1093'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 249000000991
# OriginName - Duncan_Road
# DestinationRef - 2400A000710A
# DestinationName - The_Cannon
# OriginAimedDepartureTime - 2023-01-04T14:53:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T15:38:00+00:00
# VehicleLocation - {'Longitude': '0.518531', 'Latitude': '51.273633'}
# BlockRef - 0588
# VehicleRef - 6474
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1453'}}, 'VehicleUniqueId': '6474'}
# 2023-01-04T20:37:20+00:00
# LineRef - 5
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4003'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A073520A
# OriginName - The_Swan
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2023-01-04T19:40:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:40:00+00:00
# VehicleLocation - {'Longitude': '0.523834', 'Latitude': '51.274018'}
# BlockRef - 0517
# VehicleRef - 4057
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '1940'}}, 'VehicleUniqueId': '4057'}
# 2023-01-04T19:10:16+00:00
# LineRef - 190
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1090'}
# PublishedLineName - 190
# OperatorRef - AKSS
# OriginRef - 2400109567
# OriginName - Barrack_Row
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:35:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:16:00+00:00
# VehicleLocation - {'Longitude': '0.52365', 'Latitude': '51.384155'}
# BlockRef - 0353
# VehicleRef - 4263
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '190', 'JourneyCode': '1835'}}, 'VehicleUniqueId': '4263'}
# 2022-12-18T16:55:50+00:00
# LineRef - 89
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-18', 'DatedVehicleJourneyRef': '7029'}
# PublishedLineName - 89
# OperatorRef - AKSS
# OriginRef - 2400A004480A
# OriginName - Spice_Lounge
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2022-12-18T16:28:00+00:00
# DestinationAimedArrivalTime - 2022-12-18T16:50:00+00:00
# VehicleLocation - {'Longitude': '0.520916', 'Latitude': '51.272643'}
# BlockRef - 0356
# VehicleRef - 4063
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '89', 'JourneyCode': '1628'}}, 'VehicleUniqueId': '4063'}
# 2023-01-04T23:04:33+00:00
# LineRef - 3
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1091'}
# PublishedLineName - 3
# OperatorRef - AKSS
# OriginRef - 2400A002430A
# OriginName - Maidstone_Hospital
# DestinationRef - 2400A050670A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T23:00:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:16:00+00:00
# VehicleLocation - {'Longitude': '0.482626', 'Latitude': '51.270483'}
# Bearing - 176.0
# BlockRef - 0310
# VehicleRef - 6138
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4003', 'JourneyCode': '2300'}}, 'VehicleUniqueId': '6138'}
# 2023-01-04T23:04:53+00:00
# LineRef - 166
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4012'}
# PublishedLineName - 166
# OperatorRef - AKSS
# OriginRef - 2490101076
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000872
# DestinationName - The_Kestrel_Shopping_Centre
# OriginAimedDepartureTime - 2023-01-04T23:15:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:36:00+00:00
# VehicleLocation - {'Longitude': '0.524996', 'Latitude': '51.385621'}
# BlockRef - 0101
# VehicleRef - 4313
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '166', 'JourneyCode': '2315'}}, 'VehicleUniqueId': '4313'}
# 2022-12-01T16:43:09+00:00
# LineRef - 653
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-01', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 653
# OperatorRef - AKSS
# OriginRef - 249000000311
# OriginName - Grammar_Schools
# DestinationRef - 2490101139
# DestinationName - Marsh_Road
# OriginAimedDepartureTime - 2022-12-01T15:25:00+00:00
# DestinationAimedArrivalTime - 2022-12-01T16:35:00+00:00
# VehicleLocation - {'Longitude': '0.426313', 'Latitude': '51.349698'}
# BlockRef - 0514
# VehicleRef - 6405
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '653', 'JourneyCode': '1525'}}, 'VehicleUniqueId': '6405'}
# 2023-01-04T21:27:33+00:00
# LineRef - 7
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1063'}
# PublishedLineName - 7
# OperatorRef - AKSS
# OriginRef - 2400A013900A
# OriginName - Railway_Station
# DestinationRef - 2400A050670A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T20:25:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T21:29:00+00:00
# VehicleLocation - {'Longitude': '0.527126', 'Latitude': '51.2726'}
# BlockRef - 0503
# VehicleRef - 6135
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4507', 'JourneyCode': '2025'}}, 'VehicleUniqueId': '6135'}
# 2023-01-04T17:59:01+00:00
# LineRef - 155
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1016'}
# PublishedLineName - 155
# OperatorRef - AKSS
# OriginRef - 249000000378
# OriginName - Village_Surgery
# DestinationRef - 2490101065
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T17:46:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:02:00+00:00
# VehicleLocation - {'Longitude': '0.524186', 'Latitude': '51.385161'}
# BlockRef - 0392
# VehicleRef - 4293
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5155', 'JourneyCode': '1746'}}, 'VehicleUniqueId': '4293'}
# 2023-01-04T20:43:42+00:00
# LineRef - 71
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1075'}
# PublishedLineName - 71
# OperatorRef - AKSS
# OriginRef - 2400A060530R
# OriginName - Railway_Station
# DestinationRef - 2400A050700A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T19:55:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:42:00+00:00
# VehicleLocation - {'Longitude': '0.526715', 'Latitude': '51.272398'}
# BlockRef - 0504
# VehicleRef - 4471
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '71', 'JourneyCode': '1955'}}, 'VehicleUniqueId': '4471'}
# 2023-01-03T14:56:48+00:00
# LineRef - 132
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-03', 'DatedVehicleJourneyRef': '1065'}
# PublishedLineName - 132
# OperatorRef - AKSS
# OriginRef - 2490101071
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000823
# DestinationName - Hempstead_Valley_Shopping_Centre
# OriginAimedDepartureTime - 2023-01-03T14:00:00+00:00
# DestinationAimedArrivalTime - 2023-01-03T14:40:00+00:00
# VehicleLocation - {'Longitude': '0.572546', 'Latitude': '51.34033'}
# BlockRef - 0333
# VehicleRef - 4314
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '132', 'JourneyCode': '1400'}}, 'VehicleUniqueId': '4314'}
# 2023-01-03T08:11:28+00:00
# LineRef - 334
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-03', 'DatedVehicleJourneyRef': '1005'}
# PublishedLineName - 334
# OperatorRef - AKSS
# OriginRef - 2400A012360A
# OriginName - Railway_Station
# DestinationRef - 2400107194
# DestinationName - Boys__Grammar_School
# OriginAimedDepartureTime - 2023-01-03T06:25:00+00:00
# DestinationAimedArrivalTime - 2023-01-03T08:18:00+00:00
# VehicleLocation - {'Longitude': '0.526561', 'Latitude': '51.272003'}
# Bearing - 336.0
# BlockRef - 0305
# VehicleRef - 4284
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4334', 'JourneyCode': '0625'}}, 'VehicleUniqueId': '4284'}
# 2022-12-31T10:04:25+00:00
# LineRef - 101
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-31', 'DatedVehicleJourneyRef': '6023'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 249000000991
# OriginName - Duncan_Road
# DestinationRef - 2400A000710A
# DestinationName - The_Cannon
# OriginAimedDepartureTime - 2022-12-31T09:17:00+00:00
# DestinationAimedArrivalTime - 2022-12-31T10:02:00+00:00
# VehicleLocation - {'Longitude': '0.519805', 'Latitude': '51.272683'}
# BlockRef - 0587
# VehicleRef - 6478
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '0917'}}, 'VehicleUniqueId': '6478'}
# 2023-01-04T23:02:08+00:00
# LineRef - 101
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1157'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 249000000408
# OriginName - Beechings_Green
# DestinationRef - 2490101075
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T23:12:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:35:00+00:00
# VehicleLocation - {'Longitude': '0.592031', 'Latitude': '51.374658'}
# BlockRef - 0588
# VehicleRef - 4273
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '2312'}}, 'VehicleUniqueId': '4273'}
# 2023-01-04T18:43:49+00:00
# LineRef - 182
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1121'}
# PublishedLineName - 182
# OperatorRef - AKSS
# OriginRef - 249000000408
# OriginName - Beechings_Green
# DestinationRef - 2490101063
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:20:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:46:00+00:00
# VehicleLocation - {'Longitude': '0.52385', 'Latitude': '51.384678'}
# BlockRef - 0345
# VehicleRef - 6402
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '182', 'JourneyCode': '1820'}}, 'VehicleUniqueId': '6402'}
# 2023-01-04T19:54:58+00:00
# LineRef - 190
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4010'}
# PublishedLineName - 190
# OperatorRef - AKSS
# OriginRef - 2400109567
# OriginName - Barrack_Row
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T19:20:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:59:00+00:00
# VehicleLocation - {'Longitude': '0.523945', 'Latitude': '51.384885'}
# BlockRef - 0352
# VehicleRef - 4224
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '190', 'JourneyCode': '1920'}}, 'VehicleUniqueId': '4224'}
# 2023-01-04T17:11:49+00:00
# LineRef - 182
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1103'}
# PublishedLineName - 182
# OperatorRef - AKSS
# OriginRef - 249000000408
# OriginName - Beechings_Green
# DestinationRef - 2490101063
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T16:27:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:53:00+00:00
# VehicleLocation - {'Longitude': '0.52509', 'Latitude': '51.385335'}
# BlockRef - 0344
# VehicleRef - 4318
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '182', 'JourneyCode': '1627'}}, 'VehicleUniqueId': '4318'}
# 2023-01-04T18:07:06+00:00
# LineRef - X1
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4020'}
# PublishedLineName - X1
# OperatorRef - AKSS
# OriginRef - 2400A071670A
# OriginName - Asda
# DestinationRef - 2400A000620A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2023-01-04T17:20:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:05:00+00:00
# VehicleLocation - {'Longitude': '0.526525', 'Latitude': '51.273785'}
# BlockRef - 0332
# VehicleRef - 4073
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': 'X1', 'JourneyCode': '1720'}}, 'VehicleUniqueId': '4073'}
# 2023-01-04T19:49:12+00:00
# LineRef - 191
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1087'}
# PublishedLineName - 191
# OperatorRef - AKSS
# OriginRef - 249000000103
# OriginName - High_Street
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:43:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:47:00+00:00
# VehicleLocation - {'Longitude': '0.551245', 'Latitude': '51.382718'}
# BlockRef - 0507
# VehicleRef - 6410
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '191', 'JourneyCode': '1843'}}, 'VehicleUniqueId': '6410'}
# 2023-01-04T18:29:12+00:00
# LineRef - 12
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4007'}
# PublishedLineName - 12
# OperatorRef - AKSS
# OriginRef - 2400A022950A
# OriginName - The_Vine
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T17:40:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:32:00+00:00
# VehicleLocation - {'Longitude': '0.52121', 'Latitude': '51.27309'}
# BlockRef - 0355
# VehicleRef - 4460
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '12', 'JourneyCode': '1740'}}, 'VehicleUniqueId': '4460'}
# 2023-01-04T19:13:43+00:00
# LineRef - 177
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1191'}
# PublishedLineName - 177
# OperatorRef - AKSS
# OriginRef - 2400A034340A
# OriginName - Alexandra_Hospital
# DestinationRef - 2490101070
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:35:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:11:00+00:00
# VehicleLocation - {'Longitude': '0.52444', 'Latitude': '51.387336'}
# BlockRef - 0304
# VehicleRef - 4308
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '177', 'JourneyCode': '1835'}}, 'VehicleUniqueId': '4308'}
# 2023-01-04T23:05:00+00:00
# LineRef - 191
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4015'}
# PublishedLineName - 191
# OperatorRef - AKSS
# OriginRef - 249000000083
# OriginName - Wylie_Road
# DestinationRef - 2490101069
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T22:50:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:16:00+00:00
# VehicleLocation - {'Longitude': '0.496876', 'Latitude': '51.398733'}
# Bearing - 234.0
# BlockRef - 0174
# VehicleRef - 6428
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '191', 'JourneyCode': '2250'}}, 'VehicleUniqueId': '6428'}
# 2023-01-04T17:50:58+00:00
# LineRef - 182
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1106'}
# PublishedLineName - 182
# OperatorRef - AKSS
# OriginRef - 2490101067
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000408
# DestinationName - Beechings_Green
# OriginAimedDepartureTime - 2023-01-04T17:27:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T17:54:00+00:00
# VehicleLocation - {'Longitude': '0.582528', 'Latitude': '51.376048'}
# BlockRef - 0522
# VehicleRef - 4271
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '182', 'JourneyCode': '1727'}}, 'VehicleUniqueId': '4271'}
# 2023-01-04T21:25:40+00:00
# LineRef - 82
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1143'}
# PublishedLineName - 82
# OperatorRef - AKSS
# OriginRef - 2400A001090A
# OriginName - Parade
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T21:08:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T21:25:00+00:00
# VehicleLocation - {'Longitude': '0.521788', 'Latitude': '51.273538'}
# BlockRef - 0354
# VehicleRef - 4450
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '82', 'JourneyCode': '2108'}}, 'VehicleUniqueId': '4450'}
# 2023-01-04T23:04:43+00:00
# LineRef - 5
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4005'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A073520A
# OriginName - The_Swan
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2023-01-04T21:53:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T22:54:00+00:00
# VehicleLocation - {'Longitude': '0.526665', 'Latitude': '51.272471'}
# BlockRef - 0315
# VehicleRef - 4056
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '2153'}}, 'VehicleUniqueId': '4056'}
# 2023-01-04T19:32:43+00:00
# LineRef - 191
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1074'}
# PublishedLineName - 191
# OperatorRef - AKSS
# OriginRef - 2490101079
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000103
# DestinationName - High_Street
# OriginAimedDepartureTime - 2023-01-04T18:24:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:29:00+00:00
# VehicleLocation - {'Longitude': '0.71279', 'Latitude': '51.456355'}
# BlockRef - 0502
# VehicleRef - 6420
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '191', 'JourneyCode': '1824'}}, 'VehicleUniqueId': '6420'}
# 2023-01-04T19:17:01+00:00
# LineRef - 85
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1123'}
# PublishedLineName - 85
# OperatorRef - AKSS
# OriginRef - 2400A001290A
# OriginName - Freeman_Way
# DestinationRef - 2400A050610A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T19:05:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:20:00+00:00
# VehicleLocation - {'Longitude': '0.526721', 'Latitude': '51.271776'}
# Bearing - 4.0
# BlockRef - 0353
# VehicleRef - 6448
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '85', 'JourneyCode': '1905'}}, 'VehicleUniqueId': '6448'}
# 2023-01-04T19:18:40+00:00
# LineRef - 132
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1100'}
# PublishedLineName - 132
# OperatorRef - AKSS
# OriginRef - 249000000823
# OriginName - Hempstead_Valley_Shopping_Centre
# DestinationRef - 2490101071
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:45:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:20:00+00:00
# VehicleLocation - {'Longitude': '0.523795', 'Latitude': '51.384691'}
# BlockRef - 0332
# VehicleRef - 4281
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '132', 'JourneyCode': '1845'}}, 'VehicleUniqueId': '4281'}
# 2023-01-04T18:49:43+00:00
# LineRef - 175
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1180'}
# PublishedLineName - 175
# OperatorRef - AKSS
# OriginRef - 249000000756
# OriginName - King_Street
# DestinationRef - 2490101077
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:33:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:54:00+00:00
# VehicleLocation - {'Longitude': '0.525265', 'Latitude': '51.385481'}
# BlockRef - 0302
# VehicleRef - 4315
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '175', 'JourneyCode': '1833'}}, 'VehicleUniqueId': '4315'}
# 2023-01-04T19:05:55+00:00
# LineRef - 82
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1129'}
# PublishedLineName - 82
# OperatorRef - AKSS
# OriginRef - 2400A001090A
# OriginName - Parade
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T18:40:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:00:00+00:00
# VehicleLocation - {'Longitude': '0.523673', 'Latitude': '51.260263'}
# BlockRef - 0313
# VehicleRef - 6143
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '82', 'JourneyCode': '1840'}}, 'VehicleUniqueId': '6143'}
# 2023-01-04T16:26:56+00:00
# LineRef - 575
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1000'}
# PublishedLineName - 575
# OperatorRef - AKSS
# OriginRef - 2400A000300A
# OriginName - Oakwood_Park
# DestinationRef - 2400A014540A
# DestinationName - Co_op
# OriginAimedDepartureTime - 2023-01-04T15:40:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:25:00+00:00
# VehicleLocation - {'Longitude': '0.444533', 'Latitude': '51.337513'}
# BlockRef - 0542
# VehicleRef - 6439
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '575', 'JourneyCode': '1540'}}, 'VehicleUniqueId': '6439'}
# 2023-01-04T18:42:25+00:00
# LineRef - 700
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1054'}
# PublishedLineName - 700
# OperatorRef - AKSS
# OriginRef - 2400A070100A
# OriginName - Bus_Station
# DestinationRef - 2490101072
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:04:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:45:00+00:00
# VehicleLocation - {'Longitude': '0.523969', 'Latitude': '51.3848'}
# BlockRef - 0403
# VehicleRef - 4290
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '700', 'JourneyCode': '1804'}}, 'VehicleUniqueId': '4290'}
# 2023-01-04T16:52:05+00:00
# LineRef - 771
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4000'}
# PublishedLineName - 771
# OperatorRef - AKSS
# OriginRef - 2400A035930A
# OriginName - Weald_of_Kent_School
# DestinationRef - 2400A000080A
# DestinationName - High_Street
# OriginAimedDepartureTime - 2023-01-04T15:50:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:50:00+00:00
# VehicleLocation - {'Longitude': '0.408335', 'Latitude': '51.294068'}
# BlockRef - 0513
# VehicleRef - 4106
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '771', 'JourneyCode': '1550'}}, 'VehicleUniqueId': '4106'}
# 2023-01-04T23:04:49+00:00
# LineRef - 12
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4024'}
# PublishedLineName - 12
# OperatorRef - AKSS
# OriginRef - 2400A000640A
# OriginName - Royal_Star_Arcade
# DestinationRef - 2400A036440A
# DestinationName - Railway_Station_Forecourt
# OriginAimedDepartureTime - 2023-01-04T23:05:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:33:00+00:00
# VehicleLocation - {'Longitude': '0.521773', 'Latitude': '51.273331'}
# BlockRef - 0514
# VehicleRef - 4066
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '12', 'JourneyCode': '2305'}}, 'VehicleUniqueId': '4066'}
# 2023-01-04T18:08:47+00:00
# LineRef - 3
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1067'}
# PublishedLineName - 3
# OperatorRef - AKSS
# OriginRef - 2400A002430A
# OriginName - Maidstone_Hospital
# DestinationRef - 2400A050670A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T17:48:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:07:00+00:00
# VehicleLocation - {'Longitude': '0.526761', 'Latitude': '51.27334'}
# BlockRef - 0362
# VehicleRef - 4470
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4003', 'JourneyCode': '1748'}}, 'VehicleUniqueId': '4470'}
# 2023-01-04T16:33:06+00:00
# LineRef - 692
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1002'}
# PublishedLineName - 692
# OperatorRef - AKSS
# OriginRef - 249000000309
# OriginName - Breton_Road
# DestinationRef - 249000000088
# DestinationName - The_Nags_Head
# OriginAimedDepartureTime - 2023-01-04T15:28:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:22:00+00:00
# VehicleLocation - {'Longitude': '0.648565', 'Latitude': '51.473486'}
# BlockRef - 0518
# VehicleRef - 4319
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '692', 'JourneyCode': '1528'}}, 'VehicleUniqueId': '4319'}
# 2023-01-04T20:37:24+00:00
# LineRef - 5
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1050'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A000690A
# OriginName - King_Street
# DestinationRef - 2400A022860A
# DestinationName - The_Swan
# OriginAimedDepartureTime - 2023-01-04T18:55:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:57:00+00:00
# VehicleLocation - {'Longitude': '0.52436', 'Latitude': '51.260931'}
# BlockRef - 0527
# VehicleRef - 4120
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '1855'}}, 'VehicleUniqueId': '4120'}
# 2023-01-04T17:34:54+00:00
# LineRef - 182
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1109'}
# PublishedLineName - 182
# OperatorRef - AKSS
# OriginRef - 249000000408
# OriginName - Beechings_Green
# DestinationRef - 2490101063
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T17:08:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T17:34:00+00:00
# VehicleLocation - {'Longitude': '0.549875', 'Latitude': '51.386358'}
# Bearing - 238.0
# BlockRef - 0326
# VehicleRef - 4317
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '182', 'JourneyCode': '1708'}}, 'VehicleUniqueId': '4317'}
# 2023-01-04T19:53:57+00:00
# LineRef - 89
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1048'}
# PublishedLineName - 89
# OperatorRef - AKSS
# OriginRef - 2400A000690A
# OriginName - King_Street
# DestinationRef - 2400A004480A
# DestinationName - Spice_Lounge
# OriginAimedDepartureTime - 2023-01-04T19:41:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:02:00+00:00
# VehicleLocation - {'Longitude': '0.52584', 'Latitude': '51.271356'}
# BlockRef - 0353
# VehicleRef - 6516
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '89', 'JourneyCode': '1941'}}, 'VehicleUniqueId': '6516'}
# 2023-01-04T19:08:53+00:00
# LineRef - 166
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1125'}
# PublishedLineName - 166
# OperatorRef - AKSS
# OriginRef - 249000000872
# OriginName - The_Kestrel_Shopping_Centre
# DestinationRef - 2490101063
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:50:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:18:00+00:00
# VehicleLocation - {'Longitude': '0.524795', 'Latitude': '51.385455'}
# BlockRef - 0325
# VehicleRef - 4289
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '166', 'JourneyCode': '1850'}}, 'VehicleUniqueId': '4289'}
# 2023-01-04T08:10:03+00:00
# LineRef - 166
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1021'}
# PublishedLineName - 166
# OperatorRef - AKSS
# OriginRef - 249000000872
# OriginName - The_Kestrel_Shopping_Centre
# DestinationRef - 2490101063
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T08:04:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T08:38:00+00:00
# VehicleLocation - {'Longitude': '0.544196', 'Latitude': '51.33498'}
# BlockRef - 0322
# VehicleRef - 4312
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '166', 'JourneyCode': '0804'}}, 'VehicleUniqueId': '4312'}
# 2023-01-04T19:31:56+00:00
# LineRef - 334
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1031'}
# PublishedLineName - 334
# OperatorRef - AKSS
# OriginRef - 2400A012350A
# OriginName - Tesco
# DestinationRef - 2400A050660A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:15:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:39:00+00:00
# VehicleLocation - {'Longitude': '0.526526', 'Latitude': '51.27355'}
# BlockRef - 0303
# VehicleRef - 4282
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4334', 'JourneyCode': '1815'}}, 'VehicleUniqueId': '4282'}
# 2023-01-04T16:20:19+00:00
# LineRef - 658
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 658
# OperatorRef - AKSS
# OriginRef - 249000000311
# OriginName - Grammar_Schools
# DestinationRef - 2400A074460A
# DestinationName - Boxley_Road
# OriginAimedDepartureTime - 2023-01-04T15:30:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:09:00+00:00
# VehicleLocation - {'Longitude': '0.542125', 'Latitude': '51.32805'}
# BlockRef - 0513
# VehicleRef - 6401
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '658', 'JourneyCode': '1530'}}, 'VehicleUniqueId': '6401'}
# 2023-01-04T16:13:25+00:00
# LineRef - 100
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1013'}
# PublishedLineName - 100
# OperatorRef - AKSS
# OriginRef - 249000000125
# OriginName - Goldcrest_Drive
# DestinationRef - 2490101073
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T15:56:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:04:00+00:00
# VehicleLocation - {'Longitude': '0.550513', 'Latitude': '51.38253'}
# BlockRef - 0333
# VehicleRef - 4292
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '100', 'JourneyCode': '1556'}}, 'VehicleUniqueId': '4292'}
# 2023-01-04T22:32:41+00:00
# LineRef - 7
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1067'}
# PublishedLineName - 7
# OperatorRef - AKSS
# OriginRef - 2400A013900A
# OriginName - Railway_Station
# DestinationRef - 2400A050670A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T21:25:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T22:29:00+00:00
# VehicleLocation - {'Longitude': '0.526745', 'Latitude': '51.273446'}
# BlockRef - 0301
# VehicleRef - 4075
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4007', 'JourneyCode': '2125'}}, 'VehicleUniqueId': '4075'}
# 2023-01-04T19:57:28+00:00
# LineRef - 132
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1104'}
# PublishedLineName - 132
# OperatorRef - AKSS
# OriginRef - 249000000823
# OriginName - Hempstead_Valley_Shopping_Centre
# DestinationRef - 2490101071
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T19:25:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:00:00+00:00
# VehicleLocation - {'Longitude': '0.525326', 'Latitude': '51.385451'}
# BlockRef - 0334
# VehicleRef - 4054
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '132', 'JourneyCode': '1925'}}, 'VehicleUniqueId': '4054'}
# 2023-01-04T17:25:50+00:00
# LineRef - 132
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1084'}
# PublishedLineName - 132
# OperatorRef - AKSS
# OriginRef - 249000000823
# OriginName - Hempstead_Valley_Shopping_Centre
# DestinationRef - 2490101071
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T16:42:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T17:25:00+00:00
# VehicleLocation - {'Longitude': '0.529363', 'Latitude': '51.37974'}
# BlockRef - 0510
# VehicleRef - 6442
# ...
# 2023-01-04T19:18:30+00:00
# LineRef - 176
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1185'}
# PublishedLineName - 176
# OperatorRef - AKSS
# OriginRef - 2490101070
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000614
# DestinationName - Plantation_Road
# OriginAimedDepartureTime - 2023-01-04T18:54:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:23:00+00:00
# VehicleLocation - {'Longitude': '0.573703', 'Latitude': '51.388435'}
# BlockRef - 0101
# VehicleRef - 1654
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '176', 'JourneyCode': '1854'}}, 'VehicleUniqueId': '1654'}
# 2023-01-04T16:41:20+00:00
# LineRef - 659
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1001'}
# PublishedLineName - 659
# OperatorRef - AKSS
# OriginRef - 249000000311
# OriginName - Grammar_Schools
# DestinationRef - 249000000990
# DestinationName - Bus_Depot
# OriginAimedDepartureTime - 2023-01-04T15:30:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T16:43:00+00:00
# VehicleLocation - {'Longitude': '0.551126', 'Latitude': '51.38258'}
# BlockRef - 0515
# VehicleRef - 6471
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '659', 'JourneyCode': '1530'}}, 'VehicleUniqueId': '6471'}
# 2022-12-29T19:01:16+00:00
# LineRef - 71
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-29', 'DatedVehicleJourneyRef': '6068'}
# PublishedLineName - 71
# OperatorRef - AKSS
# OriginRef - 2400A050700A
# OriginName - Chequers_Bus_Station
# DestinationRef - 2400A005010A
# DestinationName - Lunsford_Park_Tesco
# OriginAimedDepartureTime - 2022-12-29T18:30:00+00:00
# DestinationAimedArrivalTime - 2022-12-29T19:03:00+00:00
# VehicleLocation - {'Longitude': '0.441035', 'Latitude': '51.310151'}
# BlockRef - 0504
# VehicleRef - 4463
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '71', 'JourneyCode': '1830'}}, 'VehicleUniqueId': '4463'}
# 2023-01-04T23:04:57+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1148'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A050680A
# OriginName - Chequers_Bus_Station
# DestinationRef - 2490101068
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T22:40:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T23:04:00+00:00
# VehicleLocation - {'Longitude': '0.532308', 'Latitude': '51.392408'}
# Bearing - 114.0
# BlockRef - 0582
# VehicleRef - 6528
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '2240'}}, 'VehicleUniqueId': '6528'}
# 2023-01-04T20:02:41+00:00
# LineRef - 1
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1091'}
# PublishedLineName - 1
# OperatorRef - AKSS
# OriginRef - 249000000700
# OriginName - Chatham_Railway_Station
# DestinationRef - 249000000841
# DestinationName - The_Strand
# OriginAimedDepartureTime - 2023-01-04T19:37:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:01:00+00:00
# VehicleLocation - {'Longitude': '0.552991', 'Latitude': '51.395093'}
# BlockRef - 0371
# VehicleRef - 4291
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5001', 'JourneyCode': '1937'}}, 'VehicleUniqueId': '4291'}
# 2023-01-04T19:15:38+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1122'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A000780A
# OriginName - Pudding_Lane
# DestinationRef - 249000000408
# DestinationName - Beechings_Green
# OriginAimedDepartureTime - 2023-01-04T18:20:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:18:00+00:00
# VehicleLocation - {'Longitude': '0.592013', 'Latitude': '51.374783'}
# BlockRef - 0581
# VehicleRef - 6484
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1820'}}, 'VehicleUniqueId': '6484'}
# 2023-01-04T19:11:04+00:00
# LineRef - 140
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1086'}
# PublishedLineName - 140
# OperatorRef - AKSS
# OriginRef - 249000000040
# OriginName - Bligh_Way_Shops
# DestinationRef - 2490101072
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:47:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:11:00+00:00
# VehicleLocation - {'Longitude': '0.524946', 'Latitude': '51.385585'}
# BlockRef - 0520
# VehicleRef - 4060
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '140', 'JourneyCode': '1847'}}, 'VehicleUniqueId': '4060'}
# 2023-01-04T20:43:07+00:00
# LineRef - 3
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1081'}
# PublishedLineName - 3
# OperatorRef - AKSS
# OriginRef - 2400A002430A
# OriginName - Maidstone_Hospital
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T20:30:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:44:00+00:00
# VehicleLocation - {'Longitude': '0.521534', 'Latitude': '51.273375'}
# BlockRef - 0360
# VehicleRef - 4013
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4003', 'JourneyCode': '2030'}}, 'VehicleUniqueId': '4013'}
# 2023-01-04T19:33:22+00:00
# LineRef - 177
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1178'}
# PublishedLineName - 177
# OperatorRef - AKSS
# OriginRef - 2490101077
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000243
# DestinationName - Village_Centre
# OriginAimedDepartureTime - 2023-01-04T18:51:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:21:00+00:00
# VehicleLocation - {'Longitude': '0.551253', 'Latitude': '51.385573'}
# BlockRef - 0308
# VehicleRef - 1642
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '177', 'JourneyCode': '1851'}}, 'VehicleUniqueId': '1642'}
# 2023-01-02T09:29:12+00:00
# LineRef - 101
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-02', 'DatedVehicleJourneyRef': '7005'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 249000000406
# OriginName - Shops
# DestinationRef - 2400A000710A
# DestinationName - The_Cannon
# OriginAimedDepartureTime - 2023-01-02T09:20:00+00:00
# DestinationAimedArrivalTime - 2023-01-02T10:19:00+00:00
# VehicleLocation - {'Longitude': '0.567', 'Latitude': '51.381663'}
# BlockRef - 0583
# VehicleRef - 6479
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '0920'}}, 'VehicleUniqueId': '6479'}
# 2022-12-31T12:42:37+00:00
# LineRef - 182
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-31', 'DatedVehicleJourneyRef': '6054'}
# PublishedLineName - 182
# OperatorRef - AKSS
# OriginRef - 2490101067
# OriginName - Waterfront_Bus_Station
# DestinationRef - 249000000408
# DestinationName - Beechings_Green
# OriginAimedDepartureTime - 2022-12-31T12:38:00+00:00
# DestinationAimedArrivalTime - 2022-12-31T13:04:00+00:00
# VehicleLocation - {'Longitude': '0.523889', 'Latitude': '51.384755'}
# BlockRef - 0345
# VehicleRef - 4266
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '182', 'JourneyCode': '1238'}}, 'VehicleUniqueId': '4266'}
# 2023-01-04T16:56:53+00:00
# LineRef - 7
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1043'}
# PublishedLineName - 7
# OperatorRef - AKSS
# OriginRef - 2400A013900A
# OriginName - Railway_Station
# DestinationRef - 2400A050670A
# DestinationName - Chequers_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T15:14:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T17:01:00+00:00
# VehicleLocation - {'Longitude': '0.521023', 'Latitude': '51.27249'}
# BlockRef - 0529
# VehicleRef - 4469
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '4007', 'JourneyCode': '1514'}}, 'VehicleUniqueId': '4469'}
# 2023-01-04T19:39:47+00:00
# LineRef - 700
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1060'}
# PublishedLineName - 700
# OperatorRef - AKSS
# OriginRef - 2400A070100A
# OriginName - Bus_Station
# DestinationRef - 2490101072
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T19:05:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:43:00+00:00
# VehicleLocation - {'Longitude': '0.522765', 'Latitude': '51.382111'}
# BlockRef - 0404
# VehicleRef - 4299
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '700', 'JourneyCode': '1905'}}, 'VehicleUniqueId': '4299'}
# 2023-01-04T19:19:42+00:00
# LineRef - 700
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1058'}
# PublishedLineName - 700
# OperatorRef - AKSS
# OriginRef - 2400A070100A
# OriginName - Bus_Station
# DestinationRef - 2490101072
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T18:44:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:22:00+00:00
# VehicleLocation - {'Longitude': '0.523948', 'Latitude': '51.384721'}
# BlockRef - 0401
# VehicleRef - 6446
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '700', 'JourneyCode': '1844'}}, 'VehicleUniqueId': '6446'}
# 2023-01-04T19:24:36+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1126'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A000780A
# OriginName - Pudding_Lane
# DestinationRef - 249000000638
# DestinationName - Duncan_Road
# OriginAimedDepartureTime - 2023-01-04T18:44:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:26:00+00:00
# VehicleLocation - {'Longitude': '0.550893', 'Latitude': '51.384386'}
# BlockRef - 0583
# VehicleRef - 6480
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1844'}}, 'VehicleUniqueId': '6480'}
# 2023-01-04T21:56:55+00:00
# LineRef - 5
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1053'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A073520A
# OriginName - The_Swan
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2023-01-04T21:03:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T22:03:00+00:00
# VehicleLocation - {'Longitude': '0.524063', 'Latitude': '51.273921'}
# BlockRef - 0528
# VehicleRef - 6522
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '2103'}}, 'VehicleUniqueId': '6522'}
# 2023-01-04T19:41:28+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1128'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A000780A
# OriginName - Pudding_Lane
# DestinationRef - 249000000638
# DestinationName - Duncan_Road
# OriginAimedDepartureTime - 2023-01-04T18:57:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:37:00+00:00
# VehicleLocation - {'Longitude': '0.550655', 'Latitude': '51.384475'}
# BlockRef - 0584
# VehicleRef - 6477
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '1857'}}, 'VehicleUniqueId': '6477'}
# 2023-01-04T20:13:22+00:00
# LineRef - 82
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1137'}
# PublishedLineName - 82
# OperatorRef - AKSS
# OriginRef - 2400A001090A
# OriginName - Parade
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T19:50:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T20:07:00+00:00
# VehicleLocation - {'Longitude': '0.523616', 'Latitude': '51.26023'}
# BlockRef - 0315
# VehicleRef - 4296
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '82', 'JourneyCode': '1950'}}, 'VehicleUniqueId': '4296'}
# 2023-01-04T18:24:48+00:00
# LineRef - 176
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1172'}
# PublishedLineName - 176
# OperatorRef - AKSS
# OriginRef - 249000000614
# OriginName - Plantation_Road
# DestinationRef - 2490101074
# DestinationName - Waterfront_Bus_Station
# OriginAimedDepartureTime - 2023-01-04T17:53:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:27:00+00:00
# VehicleLocation - {'Longitude': '0.525535', 'Latitude': '51.385011'}
# BlockRef - 0309
# VehicleRef - 4298
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '176', 'JourneyCode': '1753'}}, 'VehicleUniqueId': '4298'}
# 2023-01-04T21:59:57+00:00
# LineRef - 101
# DirectionRef - outbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1140'}
# PublishedLineName - 101
# OperatorRef - AKSS
# OriginRef - 2400A050680A
# OriginName - Chequers_Bus_Station
# DestinationRef - 249000000408
# DestinationName - Beechings_Green
# OriginAimedDepartureTime - 2023-01-04T21:10:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T22:03:00+00:00
# VehicleLocation - {'Longitude': '0.550566', 'Latitude': '51.382556'}
# BlockRef - 0589
# VehicleRef - 4270
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '101', 'JourneyCode': '2110'}}, 'VehicleUniqueId': '4270'}
# 2023-01-04T19:06:14+00:00
# LineRef - 12
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1065'}
# PublishedLineName - 12
# OperatorRef - AKSS
# OriginRef - 2400A022950A
# OriginName - The_Vine
# DestinationRef - 2400A000640A
# DestinationName - Royal_Star_Arcade
# OriginAimedDepartureTime - 2023-01-04T18:13:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T18:59:00+00:00
# VehicleLocation - {'Longitude': '0.521725', 'Latitude': '51.27344'}
# BlockRef - 0524
# VehicleRef - 4294
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '12', 'JourneyCode': '1813'}}, 'VehicleUniqueId': '4294'}
# 2022-12-08T07:16:27+00:00
# LineRef - X2
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2022-12-08', 'DatedVehicleJourneyRef': '4003'}
# PublishedLineName - X2
# OperatorRef - AKSS
# OriginRef - 2400A060500R
# OriginName - Railway_Station
# DestinationRef - 240082419
# DestinationName - Asda
# OriginAimedDepartureTime - 2022-12-08T06:55:00+00:00
# DestinationAimedArrivalTime - 2022-12-08T07:10:00+00:00
# VehicleLocation - {'Longitude': '0.402398', 'Latitude': '51.273511'}
# BlockRef - 0331
# VehicleRef - 4279
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': 'X2', 'JourneyCode': '0655'}}, 'VehicleUniqueId': '4279'}
# 2023-01-04T19:04:15+00:00
# LineRef - 5
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '1049'}
# PublishedLineName - 5
# OperatorRef - AKSS
# OriginRef - 2400A073520A
# OriginName - The_Swan
# DestinationRef - 2400A000690A
# DestinationName - King_Street
# OriginAimedDepartureTime - 2023-01-04T18:01:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T19:09:00+00:00
# VehicleLocation - {'Longitude': '0.523061', 'Latitude': '51.273918'}
# BlockRef - 0522
# VehicleRef - 4452
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '5', 'JourneyCode': '1801'}}, 'VehicleUniqueId': '4452'}
# 2023-01-04T21:22:17+00:00
# LineRef - 6X
# DirectionRef - inbound
# FramedVehicleJourneyRef - {'DataFrameRef': '2023-01-04', 'DatedVehicleJourneyRef': '4041'}
# PublishedLineName - 6X
# OperatorRef - AKSS
# OriginRef - 2400102260
# OriginName - Tunbridge_Wells_Hospital
# DestinationRef - 2400A002430A
# DestinationName - Maidstone_Hospital
# OriginAimedDepartureTime - 2023-01-04T20:45:00+00:00
# DestinationAimedArrivalTime - 2023-01-04T21:15:00+00:00
# VehicleLocation - {'Longitude': '0.483048', 'Latitude': '51.274201'}
# Bearing - 149.0
# BlockRef - 0351
# VehicleRef - 6500
# VehicleJourney - {'Operational': {'TicketMachine': {'TicketMachineServiceCode': '6X', 'JourneyCode': '2045'}}, 'VehicleUniqueId': '6500'}

# %% [markdown]
# Initial processing requirements - create a dataframe from the tracked buses data that has the following columns:
# - RecordedAtTime
# - LineRef
# - OperatorRef
# - VehicleRef
#
# Here as the data contains dates and time from different days also first we'll need to clean the data using the date on JSON file and it should match to the RecordedAtTime in the file records.
#
# Here we are collecting only the records which are in given date 04/01/2023 and time 23:05. The timestamp is used to filter out the bus route information between 5 minutes.
#
# Once we get the number of EURO III engine buses running on the road in 5 minutes we can calculate the buses in one hour and then in one day.
#
# Save filtered data in an Excel or CSV file.

# %%
from datetime import datetime, timedelta
def get_snapshot_time_from_file_name(fname):
  file_name = fname.split('/')[-1]
  file_name = file_name.split('.')[0]
  recording_date = '20' + file_name.split('_')[1]
  recording_time = file_name.split('_')[2]
  required_day = int(recording_date.split('-')[2])
  required_year = int(recording_date.split('-')[0])
  required_month= int(recording_date.split('-')[1])
  required_hour = int(recording_time.split('-')[0])
  required_minutes= int(recording_time.split('-')[1])
  snapshot_time = datetime(required_year,required_month,required_day,required_hour,required_minutes)
  return snapshot_time

def in_this_5_mins(RecordedAtTime, snapshot_time):
  format = '%Y-%m-%dT%H:%M:%S+%f:00'
  # converting the timestamp string to datetime object
  datetime_object = datetime.strptime(RecordedAtTime, format)
  return snapshot_time.timestamp() - datetime_object.timestamp() < 300

vehicle_list = []
snapshot_time = get_snapshot_time_from_file_name(file_name)
for item in bus_data:
  RecordedAtTime = item['RecordedAtTime']
  if in_this_5_mins(RecordedAtTime, snapshot_time):
    print(RecordedAtTime, snapshot_time)
    vehicle_journey_data = item['MonitoredVehicleJourney']
    LineRef = vehicle_journey_data['LineRef']
    OperatorRef = vehicle_journey_data['OperatorRef']
    VehicleRef= vehicle_journey_data['VehicleRef']
    my_dict = {'RecordedAtTime': RecordedAtTime,'LineRef': LineRef,'OperatorRef': OperatorRef, 'VehicleRef': VehicleRef}
    vehicle_list.append(my_dict)
vehicle1_df = pd.DataFrame(vehicle_list)
print(vehicle1_df)
print(vehicle1_df.info())
# Out:
# 2023-01-04T23:04:59+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:33+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:53+00:00 2023-01-04 23:05:00
# 2023-01-04T23:02:08+00:00 2023-01-04 23:05:00
# 2023-01-04T23:05:00+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:43+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:49+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:56+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:59+00:00 2023-01-04 23:05:00
# 2023-01-04T23:05:13+00:00 2023-01-04 23:05:00
# 2023-01-04T23:05:10+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:50+00:00 2023-01-04 23:05:00
# 2023-01-04T23:05:11+00:00 2023-01-04 23:05:00
# 2023-01-04T23:04:57+00:00 2023-01-04 23:05:00
#                RecordedAtTime LineRef OperatorRef VehicleRef
# 0   2023-01-04T23:04:59+00:00     101        AKSS       6412
# 1   2023-01-04T23:04:33+00:00       3        AKSS       6138
# 2   2023-01-04T23:04:53+00:00     166        AKSS       4313
# 3   2023-01-04T23:02:08+00:00     101        AKSS       4273
# 4   2023-01-04T23:05:00+00:00     191        AKSS       6428
# 5   2023-01-04T23:04:43+00:00       5        AKSS       4056
# 6   2023-01-04T23:04:49+00:00      12        AKSS       4066
# 7   2023-01-04T23:04:56+00:00       7        AKSS       4126
# 8   2023-01-04T23:04:59+00:00     132        AKSS       1651
# 9   2023-01-04T23:05:13+00:00     177        AKSS       4058
# 10  2023-01-04T23:05:10+00:00     700        AKSS       6419
# 11  2023-01-04T23:04:50+00:00      82        AKSS       6149
# 12  2023-01-04T23:05:11+00:00      71        AKSS       4071
# 13  2023-01-04T23:04:57+00:00     101        AKSS       6528
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RecordedAtTime  14 non-null     object
#  1   LineRef         14 non-null     object
#  2   OperatorRef     14 non-null     object
#  3   VehicleRef      14 non-null     object
# dtypes: object(4)
# memory usage: 576.0+ bytes
# None

# %% [markdown]
# There is an updated dataset here with the engine types for each vehicle (by vehicleRef). python-programming-for-data/updated_bus_regs.csv at main · futureCodersSE/python-programming-for-data
#
# Your next step will be to create a copy of your dataframe, with an extra column 'Emission Class' and to fill in the value for each row of data by looking up the vehicle ref and getting the emission class.
#
# This will result in a new dataframe with some null values in the Emission Class column as the list may not be completely up to date. It looks like this might be a fairly up to date version but we need to check. However, we might be able to find a trend in the vehicle refs (e.g. if the vehicle ref is greater than 6000 then the vehicle is probably a EURO VI - this may not be the case but it is worth investigating).

# %%
def get_emission_data():
  url = "https://raw.githubusercontent.com/futureCodersSE/python-programming-for-data/main/Datasets/updated_bus_regs.csv"
  df = pd.read_csv(url)
  return df

def add_emission_class(v_df):
  emissions_df = get_emission_data()

  def get_emission_class(df):
      em_list = emissions_df[emissions_df['Last tracked'] == df['VehicleRef']]['Emission Class'].tolist()
        
      if len(em_list) > 0:
         return em_list[0]
      else:
         return None

  v_df['Emission Class'] = v_df.apply(get_emission_class, axis=1)
  return v_df
# Testing
em_df = vehicle1_df.copy()
em_df['VehicleRef'] = pd.to_numeric(em_df['VehicleRef'], errors="coerce")
actual = add_emission_class(em_df)
display(actual)
# Out:
#                RecordedAtTime LineRef OperatorRef  VehicleRef Emission Class
# 0   2023-01-04T23:04:59+00:00     101        AKSS        6412       EURO III
# 1   2023-01-04T23:04:33+00:00       3        AKSS        6138       EURO III
# 2   2023-01-04T23:04:53+00:00     166        AKSS        4313        EURO VI
# 3   2023-01-04T23:02:08+00:00     101        AKSS        4273        EURO VI
# 4   2023-01-04T23:05:00+00:00     191        AKSS        6428       EURO III
# 5   2023-01-04T23:04:43+00:00       5        AKSS        4056        EURO IV
# 6   2023-01-04T23:04:49+00:00      12        AKSS        4066        EURO IV
# 7   2023-01-04T23:04:56+00:00       7        AKSS        4126        EURO VI
# 8   2023-01-04T23:04:59+00:00     132        AKSS        1651         EURO V
# 9   2023-01-04T23:05:13+00:00     177        AKSS        4058        EURO IV
# 10  2023-01-04T23:05:10+00:00     700        AKSS        6419       EURO III
# 11  2023-01-04T23:04:50+00:00      82        AKSS        6149            NaN
# 12  2023-01-04T23:05:11+00:00      71        AKSS        4071        EURO VI
# 13  2023-01-04T23:04:57+00:00     101        AKSS        6528        EURO VI

# %%
emission_copy = actual.groupby(['Emission Class']).count()
display(emission_copy)
euro_3_df = actual[actual['Emission Class'] == 'EURO III']
print("Unique number of EURO III buses on the road:",len(euro_3_df['VehicleRef'].unique()))
# Calculate EURO III vehicles in 5 minutes time
euro_3_vehicles = emission_copy['VehicleRef']['EURO III']
euro_3_vehicles_5minutes = euro_3_vehicles * 5
print("Total number of on road hours for EURO III buses:",euro_3_vehicles_5minutes) # shows number of EURO III vehicles run on the road in 5 minutes
# Out:
#                 RecordedAtTime  LineRef  OperatorRef  VehicleRef
# Emission Class
# EURO III                     4        4            4           4
# EURO IV                      3        3            3           3
# EURO V                       1        1            1           1
# EURO VI                      5        5            5           5
# Unique number of EURO III buses on the road: 4
# Total number of on road hours for EURO III buses: 20

# %% [markdown]
# Mounting and unmounting the Google Drive
# In order to be able to open and save files on Google Drive, with Python, you first need to mount the Drive.

# %%
from google.colab import drive

def mount_drive():
  drive.mount('/content/drive', force_remount=True)
  folder_name = "/content/drive/MyDrive/Colab_data"
  return folder_name

data_folder = mount_drive()
print(data_folder)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab_data

# %% [markdown]
# The code will save a copy of the file as vehicle_data.csv

# %%
def save_data(df, path):
  try:
    df.to_csv(path + "/vehicle_data.csv")
    print("File saved successfully")
  except:
    print("There was an error when trying to save the file.")
path = mount_drive()
save_data(vehicle1_df, path)
# Out:
# Mounted at /content/drive
# File saved successfully

# %%
from pandas.io.formats.info import DataFrameInfo
def save_data(df, path):
  try:
    df.to_csv(path + "/vehicle_emission_data.csv")
    print("File saved successfully")
  except:
    print("There was an error when trying to save the file.")
path = mount_drive()
save_data(actual, path)

# %% [markdown]
# After finished working with the files, you should always unmount the Drive.

# %%
def unmount_drive():
  drive.flush_and_unmount()
  print('All changes made in this colab session should now be visible in Drive.')

unmount_drive()
# Out:
# All changes made in this colab session should now be visible in Drive.

# %% [markdown]
# From above results we can see there are 20 EURO III buses run on the road in 5 minutes and 240 EURO III engine buses in one hour.
